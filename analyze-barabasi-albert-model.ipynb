# %%
import networkx as nx
import barabasi_albert_utils as utils

# %%
# data obtainment from the user
num_nodes_initial = 12
num_nodes_final = 250
m_parameter = 7

graph = nx.complete_graph(num_nodes_initial)

graph_custom = utils.barabasi_albert_network(num_nodes_initial, num_nodes_final, m_parameter, graph)
graph_regular = nx.barabasi_albert_graph(250, 7, initial_graph=graph)

# %%
utils.k_distrib(graph_custom, scale="log")
utils.k_distrib(graph_regular, scale="log")

# %%
COLOR = '#40a6d1'
nx.draw(graph_custom, alpha = .3, edge_color = COLOR, node_color = COLOR, node_size=50)
